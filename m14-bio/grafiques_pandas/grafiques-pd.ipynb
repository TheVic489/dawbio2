# %% [markdown]
# # Gráfiques Pandas
#
# ### Exemple 1

# %%
import numpy as np 
import pandas as pd
#np --> numerical panda, es una llibreria per a realitzar càlcul numèric
#les notes de dawbio amb series
student_list = ["John","Mary","Lucy","Peter", "Victor"]
grades_list  = [7,9,8,4,10]
wants_dual_list = [False,True,False,True,False]

datos: dict[str, list] = {
    "grade": grades_list,
    "dual": wants_dual_list}

students_frame = pd.DataFrame(
    index = student_list,
    data  = datos
)
students_frame.loc[:,"grade"].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Exemple 2 : Diagrama barres números aleatoris.

# %%
# Continous vars, maje a dataframe with 2 columns
# Each column will have 100 random values (ints).
# Values will range from 10 to 100 (edat) or 1 to 100 (nota).

import numpy as np 
import pandas as pd

min_value_edat = 10
min_value_nota = 1
max_value = 100

df = pd.DataFrame({ 'edat' : np.random.randint(min_value_edat, max_value ,50),
    'nota' : np.random.randint(min_value_nota, max_value , size=50)})
df.loc[:,"nota"].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Exemple 3. Diagrama de línies.

# %%
# Creem el data_range dels últims 5 anys (anual).
range_20_last_years = pd.date_range("1/1/2017", periods=5, freq='A')

df = pd.DataFrame(
    index=range_20_last_years, 
    data= {
            "Barcelona":[23,22,24,26,28],
            "Lisboa":[21,23,21,24,25],
            "Rabat":[25,23,25,30,28],
            "Andorra":[18,21,23,22,23],
        }
    )
df.index.name="Year"
display(df)
df.plot(title="Temperatures últims 5 anys",legend=True, );
# Out:
#             Barcelona  Lisboa  Rabat  Andorra
# Year
# 2017-12-31         23      21     25       18
# 2018-12-31         22      23     23       21
# 2019-12-31         24      21     25       23
# 2020-12-31         26      24     30       22
# 2021-12-31         28      25     28       23

# %% [markdown]
# ###
