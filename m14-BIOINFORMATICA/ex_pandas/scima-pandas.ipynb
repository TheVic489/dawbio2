# %%
import numpy as np
import pandas as pd


# Read scimago ranking
entries: pd.DataFrame = pd.read_csv("scimago-medicine.csv", sep=";")
entries
# Out:
#       Rank  Sourceid                                              Title  \
# 0        1     28773                 Ca-A Cancer Journal for Clinicians
# 1        2     19434                   MMWR Recommendations and Reports
# 2        3     18991                            Nature Reviews Genetics
# 3        4     21318                          Nature Reviews Immunology
# 4        5     71056  MMWR. Surveillance summaries : Morbidity and m...
# ...    ...       ...                                                ...
# 7120  7121     25412  Zhonghua kou qiang yi xue za zhi = Zhonghua ko...
# 7121  7122     21485  Zhonghua liu xing bing xue za zhi = Zhonghua l...
# 7122  7123     26726  Zhonghua nei ke za zhi [Chinese journal of int...
# 7123  7124     19324  Zhonghua wai ke za zhi [Chinese journal of sur...
# 7124  7125     20906  Zhurnal Mikrobiologii Epidemiologii i Immunobi...
#
#          Type                Issn     SJR SJR Best Quartile  H index  \
# 0     journal  15424863, 00079235  62,937                Q1      168
# 1     journal  10575987, 15458601  40,949                Q1      143
# 2     journal  14710056, 14710064  26,214                Q1      365
# 3     journal  14741741, 14741733  20,529                Q1      390
# 4     journal  15458636, 15460738  19,961                Q1      100
# ...       ...                 ...     ...               ...      ...
# 7120  journal            10020098     NaN                 -       14
# 7121  journal            02546450     NaN                 -       31
# 7122  journal            05781426     NaN                 -       18
# 7123  journal            05295815     NaN                 -       16
# 7124  journal            03729311     NaN                 -       12
#
#       Total Docs. (2020)  Total Docs. (3years)  Total Refs.  \
# 0                     47                   119         3452
# 1                     10                     9         1292
# 2                    106                   325         7332
# 3                    230                   436         9421
# 4                     32                    48          499
# ...                  ...                   ...          ...
# 7120                 150                     0            0
# 7121                 292                     0            0
# 7122                   5                     0            0
# 7123                   5                     0            0
# 7124                  53                     0         1264
#
#       Total Cites (3years)  Citable Docs. (3years) Cites / Doc. (2years)  \
# 0                    15499                      80                126,34
# 1                      492                       9                 50,00
# 2                     6348                     149                 21,22
# 3                     8200                     202                 17,33
# 4                     2235                      48                 57,77
# ...                    ...                     ...                   ...
# 7120                     0                       0                  0,00
# 7121                     0                       0                  0,00
# 7122                     0                       0                  0,00
# 7123                     0                       0                  0,00
# 7124                     0                       0                  0,00
#
#      Ref. / Doc.             Country            Region  \
# 0          73,45       United States  Northern America
# 1         129,20       United States  Northern America
# 2          69,17      United Kingdom    Western Europe
# 3          40,96      United Kingdom    Western Europe
# 4          15,59       United States  Northern America
# ...          ...                 ...               ...
# 7120        0,00               China    Asiatic Region
# 7121        0,00               China    Asiatic Region
# 7122        0,00               China    Asiatic Region
# 7123        0,00               China    Asiatic Region
# 7124       23,85  Russian Federation    Eastern Europe
#
#                                              Publisher  \
# 0                                      Wiley-Blackwell
# 1     Centers for Disease Control and Prevention (CDC)
# 2                              Nature Publishing Group
# 3                              Nature Publishing Group
# 4     Centers for Disease Control and Prevention (CDC)
# ...                                                ...
# 7120                        Zhonghua Yixuehui Zazhishe
# 7121                        Zhonghua Yixuehui Zazhishe
# 7122                        Zhonghua Yixuehui Zazhishe
# 7123                        Zhonghua Yixuehui Zazhishe
# 7124                               Izdatel'stvo S-Info
#
#                                    Coverage  \
# 0                                 1950-2020
# 1                                 1990-2020
# 2                                 2000-2020
# 3                                 2001-2020
# 4                                 2002-2020
# ...                                     ...
# 7120                        1987-2016, 2020
# 7121                        1982-2016, 2020
# 7122  1957-1959, 1979-1997, 1999-2016, 2020
# 7123       1957, 1959-1964, 1979-2016, 2020
# 7124                   1945-1947, 1954-2016
#
#                                              Categories
# 0                        Hematology (Q1); Oncology (Q1)
# 1     Epidemiology (Q1); Health Information Manageme...
# 2     Genetics (Q1); Genetics (clinical) (Q1); Molec...
# 3     Immunology (Q1); Immunology and Allergy (Q1); ...
# 4     Epidemiology (Q1); Health Information Manageme...
# ...                                                 ...
# 7120                           Medicine (miscellaneous)
# 7121                           Medicine (miscellaneous)
# 7122                           Medicine (miscellaneous)
# 7123                           Medicine (miscellaneous)
# 7124  Immunology; Medicine (miscellaneous); Microbio...
#
# [7125 rows x 20 columns]

# %%
# Provem que ha funcionat
print()
entries.loc['Tittle',"Rank",]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 3
#       1 # Provem que ha funcionat
#       2 print()
# ----> 3 entries.loc['Tittle',"Rank",]
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/pandas/core/frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/pandas/core/indexes/range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Tittle'

# %%
# Mostra el tipus de dades de totes les files, però sol la seva columna Rank
entries.loc[:,"Rank"].dtype
# Out:
# dtype('int64')

# %%
entries.index
# Out:
# RangeIndex(start=0, stop=7125, step=1)

# %%
import copy as cp
# Ficar el valor de les les entrades a h_index negatiu, si son menors de 750...
#canviar el valor de les entrades amb el **H index** menor a 750,  al seu valor amb negatiu.

entries3 = cp.deepcopy(entries)

bad_entries_mask = (entries3.loc[:,"H index"] < 350)
entries3.loc[bad_entries_mask,"H index"] = entries3.loc[bad_entries_mask,"H index"]*(-1);
entries3.sort_values(by=["H index"], axis=0, ascending=False).head(5)
# Out:
#      Rank  Sourceid                                              Title  \
# 5       6     15847                    New England Journal of Medicine
# 13     14     16590                                        Lancet, The
# 113   114     85291  JAMA - Journal of the American Medical Associa...
# 43     44     22581                                        Circulation
# 19     20     29949                       Journal of Clinical Oncology
#
#         Type                          Issn     SJR SJR Best Quartile  H index  \
# 5    journal            00284793, 15334406  19,889                Q1     1030
# 13   journal            01406736, 1474547X  13,103                Q1      762
# 113  journal  15383598, 00987484, 00029955   4,688                Q1      680
# 43   journal            00097322, 15244539   7,795                Q1      607
# 19   journal            15277755, 0732183X  10,482                Q1      548
#
#      Total Docs. (2020)  Total Docs. (3years)  Total Refs.  \
# 5                  1671                  4312        15715
# 13                 1488                  4593        16580
# 113                1793                  5000        14369
# 43                  778                  2685        22242
# 19                  583                  1890        17448
#
#      Total Cites (3years)  Citable Docs. (3years) Cites / Doc. (2years)  \
# 5                   82469                    1842                 19,08
# 13                  45581                    1227                  9,45
# 113                 30016                    2627                  5,46
# 43                  26532                    1702                  9,48
# 19                  23642                    1221                 12,29
#
#     Ref. / Doc.         Country            Region  \
# 5          9,40   United States  Northern America
# 13        11,14  United Kingdom    Western Europe
# 113        8,01   United States  Northern America
# 43        28,59   United States  Northern America
# 19        29,93   United States  Northern America
#
#                                  Publisher   Coverage  \
# 5           Massachussetts Medical Society  1945-2020
# 13                           Elsevier Ltd.  1823-2020
# 113           American Medical Association  1883-2020
# 43    Lippincott Williams and Wilkins Ltd.  1950-2020
# 19   American Society of Clinical Oncology  1983-2020
#
#                                             Categories
# 5                        Medicine (miscellaneous) (Q1)
# 13                       Medicine (miscellaneous) (Q1)
# 113                      Medicine (miscellaneous) (Q1)
# 43   Cardiology and Cardiovascular Medicine (Q1); P...
# 19   Cancer Research (Q1); Medicine (miscellaneous)...
